# %%
import pandas as pd
from IPython.display import Image
Image(filename='/home/gamer456148/Downloads/Sales.png')

# %%
df  = pd.read_csv("/home/gamer456148/Downloads/SouvenirSales.csv")
print(df)
# Out:
#       Date      Sales
# 0   Jan-95    1664.81
# 1   Feb-95    2397.53
# 2   Mar-95    2840.71
# 3   Apr-95    3547.29
# 4   May-95    3752.96
# ..     ...        ...
# 79  Aug-01   28586.52
# 80  Sep-01   30505.41
# 81  Oct-01   30821.33
# 82  Nov-01   46634.38
# 83  Dec-01  104660.67
#
# [84 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
df  = pd.read_csv("/home/gamer456148/Downloads/SouvenirSales.csv")
df.plot()
df.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
Image(filename='/home/gamer456148/Downloads/Model1view1.png')

# %%
Image(filename='/home/gamer456148/Downloads/Histoview1.png')

# %%
# Project Info
# Summary
# I didn't have Excel on my Ubuntu Linux so using XLMiner® was a nogo, will see what I can do for the upcoming weeks.
# I decided to use RapidMiner Studio for visualizing some of the plots and the layout for the models, the rest was Python Notebooks (Jupyter)
# I did a series plot, regular plot, and historgram distribution methods
# Most predictions and equations were autogenerated
# Givent the density, one would think the next sales milestone is 12000
# Please see the image below in regards to full view/results view
Image(filename='/home/gamer456148/Downloads/Resultview.png')
