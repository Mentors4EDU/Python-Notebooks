# %%
import pandas as pd
df  = pd.read_csv("Downloads/Airfares.csv")
print(df)
# Out:
#     S_CODE                  S_CITY E_CODE                  E_CITY  COUPON  \
# 0        *  Dallas/Fort Worth   TX      *  Amarillo            TX    1.00
# 1        *  Atlanta             GA      *  Baltimore/Wash Intl MD    1.06
# 2        *  Boston              MA      *  Baltimore/Wash Intl MD    1.06
# 3      ORD  Chicago             IL      *  Baltimore/Wash Intl MD    1.06
# 4      MDW  Chicago             IL      *  Baltimore/Wash Intl MD    1.06
# ..     ...                     ...    ...                     ...     ...
# 633    LGA  New York/Newark     NY      *  West Palm Beach     FL    1.08
# 634    EWR  New York/Newark     NY      *  West Palm Beach     FL    1.08
# 635      *  Philadelphia/Camden PA      *  West Palm Beach     FL    1.17
# 636    IAD  Washington          DC      *  West Palm Beach     FL    1.28
# 637    DCA  Washington          DC      *  West Palm Beach     FL    1.28
#
#      NEW VACATION   SW       HI  S_INCOME  E_INCOME    S_POP    E_POP  \
# ...

# %%
from IPython.display import Image
Image(filename='/home/gamer456148/Downloads/ScatterView.png')

# %%
# I believe the biggest indicators in regards for FARE are S_POP (population) and location.

# %%
from IPython.display import Image
Image(filename='/home/gamer456148/Downloads/View1_Scatter.png')

# %%
from IPython.display import Image
Image(filename='/home/gamer456148/Downloads/TransformationView.png')

# %%
# For sake of simplicty, I used RapidMiner Studio +  the Python extension over Skilearn and Matlab. My computer didn't have the dependencies configued.
# The graphs included were scatter and a transformaiton plot
# Predicted fair is $252

# %%
airfares_df = pd.read_csv("Downloads/Airfares.csv")
airfares_df['VACATION'] = [1 if v == 'Yes' else 0 for v in airfares_df['VACATION']]
df = pd.DataFrame([(.2, .3), (.0, .6), (.6, .0), (.2, .1)],
columns=['yes', 'no'])

# %%
# When I install Matlab, I can set category cmaps for color
# Variables like these can be used for sorting data, however in terms of plot indicators in the real world, 
# likely a better indicator as of now would be cost of living/location traveling too
